# %% [markdown]
# ## テンプレートマッチング SAD

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %matplotlib inline

# %%
def Template_matching_SAD(img, tmp):
    H,W,C = img.shape
    Ht,Wt,Ct = tmp.shape
    
    i, j = -1, -1
    v = H*W*C*255
    
    for y in range(H-Ht):
        for x in range(W-Wt):
            _v = np.sum(np.abs(img[y:y+Ht, x:x+Wt] - tmp))
            
            if _v < v:
                v = _v
                i, j = x, y
                
    out = img.copy()
    cv2.rectangle(out, pt1=(i, j), pt2=(i+Wt, j+Ht), color=(0,0,255), thickness=1)
    out = out.astype(np.uint8)
    
    print(v)
    
    return out

# %%
img = cv2.imread('../imori.jpg')
tmp = cv2.imread('../imori_part.jpg')

out = Template_matching_SAD(img, tmp)

plt.imshow(out)
cv2.imwrite('out55.jpg', out)
# Out:
# 149844
# True
